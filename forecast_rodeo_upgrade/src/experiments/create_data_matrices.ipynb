# %% [markdown]
# ## Load packages

# %%
# !pip install tables

# %%
# Autoreload packages that are modified
# %load_ext autoreload
# %autoreload 2
import h5py
import os
import sys
import xarray as xr
#import tensorflow as tf
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#if tf.test.is_gpu_available():
    #print('GPU is available')
#else:
    #print('GPU is not available')

#device_name = '/gpu:0'
#ds = xr.open_dataset('forecast_rodeo/data/dataframes/gt-contest_tmax-14d-1979-2018.h5')


####### Initial version #########

# Ensure correct working directory
#if os.path.basename(os.getcwd()) == "experiments":
    #os.chdir(os.path.join("..",".."))
##f1 = h5py.File('data/dataframes/gt-contest_tmax-14d-1979-2018.h5','r')

##Adds 'experiments' folder to path to load experiments_util
#sys.path.insert(0, 'src/experiments')
## Load general utility functions
#from experiments_util import *

######## CloubBucket Hub version ########
import os
import gcsfs
import xarray as xr

#os.environ['PERSISTENT_BUCKET']
#fs = gcsfs.GCSFileSystem()

if os.path.basename(os.getcwd()) == "experiments":
    os.chdir(os.path.join("..",".."))
from experiments_util import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Create (shared) data matrices
#
# Generates two data matrices containing all needed features that vary by date only (create_date_data) or by date and latitude/longitude (create_lat_lon_date_data) and saves them to results/regression/shared.

# %%
gt_id = "contest_tmp2m" # "contest_precip" or "contest_tmp2m"
target_horizon = "34w" # "34w" or "56w"
experiment = "regression"
#os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/srv/conda/envs/notebook'
multiflux_resolution = "monthly" #"monthly" or "daily"

date_cols = create_date_data(gt_id, target_horizon, experiment, multiflux_resolution)
lat_lon_date_cols = create_lat_lon_date_data(gt_id, target_horizon, experiment, multiflux_resolution,
                                             forecast_models=["nmme","nmme0"])
# Out:
# Loading date features
# Getting mei_shift45
# Elapsed: 0.287168025970459s
# Getting mjo_shift17
# Elapsed: 0.09813737869262695s
# Getting pca_sst_2010_shift30
# Elapsed: 0.1103670597076416s
# Getting pca_icec_2010_shift30
# Elapsed: 0.12347912788391113s
# Getting pca_wind_hgt_10_2010_shift30
# Elapsed: 0.16320419311523438s
# Getting pca_wind_hgt_100_2010_shift30
# Elapsed: 0.1557776927947998s
# Getting pca_wind_hgt_500_2010_shift30
# Elapsed: 0.08468842506408691s
# Getting pca_wind_hgt_850_2010_shift30
# Elapsed: 0.15319466590881348s
#              0
# 0   2001-01-01
# 1   2001-02-01
# 2   2001-03-01
# 3   2001-04-01
# 4   2001-05-01
# ..         ...
# 247 2021-08-01
# 248 2021-09-01
# 249 2021-10-01
# 250 2021-11-01
# 251 2021-12-01
#
# [252 rows x 1 columns]
# Elapsed: 6.4373016357421875e-06s
#              0
# 0   2001-01-01
# 1   2001-02-01
# 2   2001-03-01
# 3   2001-04-01
# 4   2001-05-01
# ..         ...
# 247 2021-08-01
# 248 2021-09-01
# 249 2021-10-01
# 250 2021-11-01
# 251 2021-12-01
#
# [252 rows x 1 columns]
# Elapsed: 6.67572021484375e-06s
#       start_date  mei_shift45  mei_rank_shift45  nip_shift45  phase_shift17
# 0     1979-01-01        0.003              33.0          3.0            NaN  \
# 1     1979-01-02        0.003              33.0          3.0            NaN
# 2     1979-01-03        0.003              33.0          3.0            NaN
# 3     1979-01-04        0.203              40.0          3.0            NaN
# 4     1979-01-05        0.203              40.0          3.0            NaN
# ...          ...          ...               ...          ...            ...
# 14684 2021-08-01          NaN               NaN          NaN            NaN
# 14685 2021-09-01          NaN               NaN          NaN            NaN
# 14686 2021-10-01          NaN               NaN          NaN            NaN
# 14687 2021-11-01          NaN               NaN          NaN            NaN
# 14688 2021-12-01          NaN               NaN          NaN            NaN
#
#        amplitude_shift17  sst_2010_1_shift30  sst_2010_2_shift30
# 0                    NaN                 NaN                 NaN  \
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 14684                NaN                 NaN                 NaN
# 14685                NaN                 NaN                 NaN
# 14686                NaN                 NaN                 NaN
# 14687                NaN                 NaN                 NaN
# 14688                NaN                 NaN                 NaN
#
#        sst_2010_3_shift30  sst_2010_4_shift30  ...
# 0                     NaN                 NaN  ...  \
# 1                     NaN                 NaN  ...
# 2                     NaN                 NaN  ...
# 3                     NaN                 NaN  ...
# 4                     NaN                 NaN  ...
# ...                   ...                 ...  ...
# 14684                 NaN                 NaN  ...
# 14685                 NaN                 NaN  ...
# 14686                 NaN                 NaN  ...
# 14687                 NaN                 NaN  ...
# 14688                 NaN                 NaN  ...
#
#        wind_hgt_850_2010_1_shift30  wind_hgt_850_2010_2_shift30
# 0                      3424.758581                 -1529.743934  \
# 1                      3314.994125                 -1532.788128
# 2                      3252.825680                 -1504.846111
# 3                      3274.513930                 -1457.872985
# 4                      3355.278766                 -1470.789935
# ...                            ...                          ...
# 14684                          NaN                          NaN
# 14685                          NaN                          NaN
# 14686                          NaN                          NaN
# 14687                          NaN                          NaN
# 14688                          NaN                          NaN
#
#        wind_hgt_850_2010_3_shift30  wind_hgt_850_2010_4_shift30
# 0                      1800.084391                   441.783453  \
# 1                      1835.684702                   426.358432
# 2                      1787.861852                   379.753671
# 3                      1670.977746                   320.789187
# 4                      1588.901754                   343.379454
# ...                            ...                          ...
# 14684                          NaN                          NaN
# 14685                          NaN                          NaN
# 14686                          NaN                          NaN
# 14687                          NaN                          NaN
# 14688                          NaN                          NaN
#
#        wind_hgt_850_2010_5_shift30  wind_hgt_850_2010_6_shift30
# 0                        -3.752238                  -361.748048  \
# 1                        -4.613801                  -356.166095
# 2                       -34.722000                  -323.800268
# 3                       -82.174408                  -332.159939
# 4                      -143.358768                  -324.124877
# ...                            ...                          ...
# 14684                          NaN                          NaN
# 14685                          NaN                          NaN
# 14686                          NaN                          NaN
# 14687                          NaN                          NaN
# 14688                          NaN                          NaN
#
#        wind_hgt_850_2010_7_shift30  wind_hgt_850_2010_8_shift30
# 0                      1076.744863                  -683.339414  \
# 1                       930.043923                  -817.419557
# 2                       775.722659                  -953.960185
# 3                       744.138289                 -1025.404163
# 4                       843.946178                 -1075.934235
# ...                            ...                          ...
# 14684                          NaN                          NaN
# 14685                          NaN                          NaN
# 14686                          NaN                          NaN
# 14687                          NaN                          NaN
# 14688                          NaN                          NaN
#
#        wind_hgt_850_2010_9_shift30  wind_hgt_850_2010_10_shift30
# 0                       -48.986002                  -2375.221186
# 1                      -125.386682                  -2296.931890
# 2                      -179.173104                  -2151.190296
# 3                      -103.820088                  -2042.212669
# 4                        47.717382                  -2027.073260
# ...                            ...                           ...
# 14684                          NaN                           NaN
# 14685                          NaN                           NaN
# 14686                          NaN                           NaN
# 14687                          NaN                           NaN
# 14688                          NaN                           NaN
#
# [14689 rows x 66 columns]
# Loading additional date features
# Elapsed: 0.0011982917785644531s
# Saving date features to results/regression1/shared/contest_tmp2m_34w/date_data-contest_tmp2m_34w.h5
# Elapsed: 0.3000476360321045s
# Finished generating date_data matrix.
# Total time elapsed: 4.356078624725342s
# Loading contest mask
# Elapsed: 0.002949237823486328s
# Loading lat lon date features
# gt_ids ['contest_rhum.sig995', 'contest_pres.sfc.gauss', 'GPP', 'RECO', 'CASM_soil_moisture', 'contest_rhum.sig995', 'contest_pres.sfc.gauss', 'GPP', 'RECO', 'CASM_soil_moisture', 'contest_rhum.sig995', 'contest_pres.sfc.gauss', 'GPP', 'RECO', 'CASM_soil_moisture']
# gt_shifts [30, 30, 30, 30, 29, 60, 60, 60, 60, 58, 365, 365, 365, 365, 365]
# anom_ids ['contest_tmp2m', 'contest_precip', 'contest_tmp2m', 'contest_precip', 'contest_tmp2m', 'contest_precip', 'contest_tmp2m']
# anom_shifts [None, 29, 29, 58, 58, 365, 365]
# past_start_deltas [29, 29]
# Getting contest_rhum.sig995_shift30
# Elapsed: 3.8107941150665283s
# Getting contest_pres.sfc.gauss_shift30
# Elapsed: 7.2026145458221436s
# Getting GPP_shift30
# GPP
# Getting : GPP
# Index(['GPP'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa1931528c0>
#          latitude  longitude       time       GPP
# 0            27.0      236.0 2001-01-31       NaN
# 1            27.0      236.0 2001-03-03       NaN
# 2            27.0      236.0 2001-03-31       NaN
# 3            27.0      236.0 2001-05-01       NaN
# 4            27.0      236.0 2001-05-31       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2021-08-31  4.745697
# 2713784      49.0      266.0 2021-10-01  4.021908
# 2713785      49.0      266.0 2021-10-31  2.503455
# 2713786      49.0      266.0 2021-12-01  2.196509
# 2713787      49.0      266.0 2021-12-31  2.124580
#
# [2713788 rows x 4 columns]
# Elapsed: 22.407143592834473s
# Getting RECO_shift30
# RECO
# Index(['RECO'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa1931536d0>
#          latitude  longitude       time      RECO
# 0            27.0      236.0 2001-01-31       NaN
# 1            27.0      236.0 2001-03-03       NaN
# 2            27.0      236.0 2001-03-31       NaN
# 3            27.0      236.0 2001-05-01       NaN
# 4            27.0      236.0 2001-05-31       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2021-08-31  4.416244
# 2713784      49.0      266.0 2021-10-01  3.749616
# 2713785      49.0      266.0 2021-10-31  2.338751
# 2713786      49.0      266.0 2021-12-01  2.026108
# 2713787      49.0      266.0 2021-12-31  1.942994
#
# [2713788 rows x 4 columns]
# Elapsed: 22.499445915222168s
# Getting CASM_soil_moisture_shift29
# CASM_soil_moisture
# Getting CASM_soil_moisture
# Index(['Unnamed: 0', 'CASM_soil_moisture'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa1937bb5b0>
#              lat      lon       date  Unnamed: 0  CASM_soil_moisture
# 0         27.170  245.749 2010-02-15     6039126            0.084919
# 1         27.170  245.749 2010-02-21     6046308            0.157514
# 2         27.170  245.749 2010-02-24     6051123            0.092499
# 3         27.170  245.749 2010-02-27     6056339            0.085496
# 4         27.170  245.749 2010-03-02     6061906            0.118049
# ...          ...      ...        ...         ...                 ...
# 14348401  48.852  265.980 2020-09-14    14314567            0.513210
# 14348402  48.852  265.980 2020-09-17    14322041            0.474884
# 14348403  48.852  265.980 2020-09-20    14329552            0.481865
# 14348404  48.852  265.980 2020-09-23    14336884            0.495370
# 14348405  48.852  265.980 2020-09-26    14344461            0.486723
#
# [14348406 rows x 5 columns]
# test de CASM              lat      lon start_date  Unnamed: 0_shift29
# 0         27.170  245.749 2010-02-15             6039126  \
# 1         27.170  245.749 2010-02-21             6046308
# 2         27.170  245.749 2010-02-24             6051123
# 3         27.170  245.749 2010-02-27             6056339
# 4         27.170  245.749 2010-03-02             6061906
# ...          ...      ...        ...                 ...
# 14348401  48.852  265.980 2020-09-14            14314567
# 14348402  48.852  265.980 2020-09-17            14322041
# 14348403  48.852  265.980 2020-09-20            14329552
# 14348404  48.852  265.980 2020-09-23            14336884
# 14348405  48.852  265.980 2020-09-26            14344461
#
#           CASM_soil_moisture_shift29
# 0                           0.084919
# 1                           0.157514
# 2                           0.092499
# 3                           0.085496
# 4                           0.118049
# ...                              ...
# 14348401                    0.513210
# 14348402                    0.474884
# 14348403                    0.481865
# 14348404                    0.495370
# 14348405                    0.486723
#
# [14348406 rows x 5 columns]
# Elapsed: 31.595460891723633s
# Getting contest_rhum.sig995_shift60
# Elapsed: 13.606546401977539s
# Getting contest_pres.sfc.gauss_shift60
# Elapsed: 12.02869725227356s
# Getting GPP_shift60
# GPP
# Getting : GPP
# Index(['GPP'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa193153880>
#          latitude  longitude       time       GPP
# 0            27.0      236.0 2001-03-02       NaN
# 1            27.0      236.0 2001-04-02       NaN
# 2            27.0      236.0 2001-04-30       NaN
# 3            27.0      236.0 2001-05-31       NaN
# 4            27.0      236.0 2001-06-30       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2021-09-30  4.745697
# 2713784      49.0      266.0 2021-10-31  4.021908
# 2713785      49.0      266.0 2021-11-30  2.503455
# 2713786      49.0      266.0 2021-12-31  2.196509
# 2713787      49.0      266.0 2022-01-30  2.124580
#
# [2713788 rows x 4 columns]
# Elapsed: 31.067959547042847s
# Getting RECO_shift60
# RECO
# Index(['RECO'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa199eedb40>
#          latitude  longitude       time      RECO
# 0            27.0      236.0 2001-03-02       NaN
# 1            27.0      236.0 2001-04-02       NaN
# 2            27.0      236.0 2001-04-30       NaN
# 3            27.0      236.0 2001-05-31       NaN
# 4            27.0      236.0 2001-06-30       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2021-09-30  4.416244
# 2713784      49.0      266.0 2021-10-31  3.749616
# 2713785      49.0      266.0 2021-11-30  2.338751
# 2713786      49.0      266.0 2021-12-31  2.026108
# 2713787      49.0      266.0 2022-01-30  1.942994
#
# [2713788 rows x 4 columns]
# Elapsed: 29.88633394241333s
# Getting CASM_soil_moisture_shift58
# CASM_soil_moisture
# Getting CASM_soil_moisture
# Index(['Unnamed: 0', 'CASM_soil_moisture'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa1a6beea70>
#              lat      lon       date  Unnamed: 0  CASM_soil_moisture
# 0         27.170  245.749 2010-03-16     6039126            0.084919
# 1         27.170  245.749 2010-03-22     6046308            0.157514
# 2         27.170  245.749 2010-03-25     6051123            0.092499
# 3         27.170  245.749 2010-03-28     6056339            0.085496
# 4         27.170  245.749 2010-03-31     6061906            0.118049
# ...          ...      ...        ...         ...                 ...
# 14348401  48.852  265.980 2020-10-13    14314567            0.513210
# 14348402  48.852  265.980 2020-10-16    14322041            0.474884
# 14348403  48.852  265.980 2020-10-19    14329552            0.481865
# 14348404  48.852  265.980 2020-10-22    14336884            0.495370
# 14348405  48.852  265.980 2020-10-25    14344461            0.486723
#
# [14348406 rows x 5 columns]
# test de CASM              lat      lon start_date  Unnamed: 0_shift58
# 0         27.170  245.749 2010-03-16             6039126  \
# 1         27.170  245.749 2010-03-22             6046308
# 2         27.170  245.749 2010-03-25             6051123
# 3         27.170  245.749 2010-03-28             6056339
# 4         27.170  245.749 2010-03-31             6061906
# ...          ...      ...        ...                 ...
# 14348401  48.852  265.980 2020-10-13            14314567
# 14348402  48.852  265.980 2020-10-16            14322041
# 14348403  48.852  265.980 2020-10-19            14329552
# 14348404  48.852  265.980 2020-10-22            14336884
# 14348405  48.852  265.980 2020-10-25            14344461
#
#           CASM_soil_moisture_shift58
# 0                           0.084919
# 1                           0.157514
# 2                           0.092499
# 3                           0.085496
# 4                           0.118049
# ...                              ...
# 14348401                    0.513210
# 14348402                    0.474884
# 14348403                    0.481865
# 14348404                    0.495370
# 14348405                    0.486723
#
# [14348406 rows x 5 columns]
# Elapsed: 32.99359941482544s
# Getting contest_rhum.sig995_shift365
# Elapsed: 21.923640489578247s
# Getting contest_pres.sfc.gauss_shift365
# Elapsed: 18.473235607147217s
# Getting GPP_shift365
# GPP
# Getting : GPP
# Index(['GPP'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa193153ac0>
#          latitude  longitude       time       GPP
# 0            27.0      236.0 2002-01-01       NaN
# 1            27.0      236.0 2002-02-01       NaN
# 2            27.0      236.0 2002-03-01       NaN
# 3            27.0      236.0 2002-04-01       NaN
# 4            27.0      236.0 2002-05-01       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2022-08-01  4.745697
# 2713784      49.0      266.0 2022-09-01  4.021908
# 2713785      49.0      266.0 2022-10-01  2.503455
# 2713786      49.0      266.0 2022-11-01  2.196509
# 2713787      49.0      266.0 2022-12-01  2.124580
#
# [2713788 rows x 4 columns]
# Elapsed: 38.032713651657104s
# Getting RECO_shift365
# RECO
# Index(['RECO'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa2661e04c0>
#          latitude  longitude       time      RECO
# 0            27.0      236.0 2002-01-01       NaN
# 1            27.0      236.0 2002-02-01       NaN
# 2            27.0      236.0 2002-03-01       NaN
# 3            27.0      236.0 2002-04-01       NaN
# 4            27.0      236.0 2002-05-01       NaN
# ...           ...        ...        ...       ...
# 2713783      49.0      266.0 2022-08-01  4.416244
# 2713784      49.0      266.0 2022-09-01  3.749616
# 2713785      49.0      266.0 2022-10-01  2.338751
# 2713786      49.0      266.0 2022-11-01  2.026108
# 2713787      49.0      266.0 2022-12-01  1.942994
#
# [2713788 rows x 4 columns]
# Elapsed: 34.24445462226868s
# Getting CASM_soil_moisture_shift365
# CASM_soil_moisture
# Getting CASM_soil_moisture
# Index(['Unnamed: 0', 'CASM_soil_moisture'], dtype='object')
# <function shift_df_new.<locals>.<lambda> at 0x7fa1931375b0>
#              lat      lon       date  Unnamed: 0  CASM_soil_moisture
# 0         27.170  245.749 2011-01-17     6039126            0.084919
# 1         27.170  245.749 2011-01-23     6046308            0.157514
# 2         27.170  245.749 2011-01-26     6051123            0.092499
# 3         27.170  245.749 2011-01-29     6056339            0.085496
# 4         27.170  245.749 2011-02-01     6061906            0.118049
# ...          ...      ...        ...         ...                 ...
# 14348401  48.852  265.980 2021-08-16    14314567            0.513210
# 14348402  48.852  265.980 2021-08-19    14322041            0.474884
# 14348403  48.852  265.980 2021-08-22    14329552            0.481865
# 14348404  48.852  265.980 2021-08-25    14336884            0.495370
# 14348405  48.852  265.980 2021-08-28    14344461            0.486723
#
# [14348406 rows x 5 columns]
# test de CASM              lat      lon start_date  Unnamed: 0_shift365
# 0         27.170  245.749 2011-01-17              6039126  \
# 1         27.170  245.749 2011-01-23              6046308
# 2         27.170  245.749 2011-01-26              6051123
# 3         27.170  245.749 2011-01-29              6056339
# 4         27.170  245.749 2011-02-01              6061906
# ...          ...      ...        ...                  ...
# 14348401  48.852  265.980 2021-08-16             14314567
# 14348402  48.852  265.980 2021-08-19             14322041
# 14348403  48.852  265.980 2021-08-22             14329552
# 14348404  48.852  265.980 2021-08-25             14336884
# 14348405  48.852  265.980 2021-08-28             14344461
#
#           CASM_soil_moisture_shift365
# 0                            0.084919
# 1                            0.157514
# 2                            0.092499
# 3                            0.085496
# 4                            0.118049
# ...                               ...
# 14348401                     0.513210
# 14348402                     0.474884
# 14348403                     0.481865
# 14348404                     0.495370
# 14348405                     0.486723
#
# [14348406 rows x 5 columns]
# Elapsed: 39.86108589172363s
# Getting nmme-tmp2m-34w_shiftNone
# Elapsed: 42.94411277770996s
# Getting nmme0-tmp2m-34w_shiftNone
# Elapsed: 29.222044706344604s
# Getting nmme-tmp2m-34w_shift15
# Elapsed: 50.04438233375549s
# Getting nmme0-tmp2m-34w_shift15
# Elapsed: 51.54189205169678s
# Getting contest_tmp2m_shiftNone with anomalies
# Elapsed: 89.71336579322815s
# Getting contest_precip_shift29 with anomalies
# Elapsed: 93.70109272003174s
# Getting contest_tmp2m_shift29 with anomalies
# Elapsed: 95.34821033477783s
# Getting contest_precip_shift58 with anomalies
# Elapsed: 98.8982880115509s
# Getting contest_tmp2m_shift58 with anomalies
# Elapsed: 102.45534539222717s
# Getting contest_precip_shift365 with anomalies
# Elapsed: 122.01711750030518s
# Getting contest_tmp2m_shift365 with anomalies
# Elapsed: 108.29684400558472s
#            lat    lon  key_2  key_3 start_date  rhum_shift30  pres_shift30
# 0         27.0  261.0      1      1 1979-01-01     57.466688  99196.743722  \
# 1         27.0  261.0      1      2 1979-01-02     58.232885  99266.965262
# 2         27.0  261.0      1      3 1979-01-03     59.704129  99400.245954
# 3         27.0  261.0      1      4 1979-01-04     61.358364  99439.889230
# 4         27.0  261.0      1      5 1979-01-05     63.133753  99465.315709
# ...        ...    ...    ...    ...        ...           ...           ...
# 44286280  49.0  258.0      5     23 2019-05-23           NaN           NaN
# 44286281  49.0  259.0      5     23 2019-05-23           NaN           NaN
# 44286282  49.0  260.0      5     23 2019-05-23           NaN           NaN
# 44286283  49.0  261.0      5     23 2019-05-23           NaN           NaN
# 44286284  49.0  262.0      5     23 2019-05-23           NaN           NaN
#
#           GPP_shift30  RECO_shift30  Unnamed: 0_shift29  ...
# 0                 NaN           NaN                 NaN  ...  \
# 1                 NaN           NaN                 NaN  ...
# 2                 NaN           NaN                 NaN  ...
# 3                 NaN           NaN                 NaN  ...
# 4                 NaN           NaN                 NaN  ...
# ...               ...           ...                 ...  ...
# 44286280          NaN           NaN                 NaN  ...
# 44286281          NaN           NaN                 NaN  ...
# 44286282          NaN           NaN                 NaN  ...
# 44286283          NaN           NaN                 NaN  ...
# 44286284          NaN           NaN                 NaN  ...
#
#           tmp2m_shift58_clim  tmp2m_shift58_anom  precip_shift365
# 0                  20.063086                 NaN         7.204428  \
# 1                  20.040854                 NaN         4.798007
# 2                  20.013098                 NaN         1.671834
# 3                  19.896152                 NaN         1.171708
# 4                  19.733871                 NaN         3.176525
# ...                      ...                 ...              ...
# 44286280                 NaN                 NaN       100.714169
# 44286281                 NaN                 NaN        45.460673
# 44286282                 NaN                 NaN        61.931758
# 44286283                 NaN                 NaN        56.646983
# 44286284                 NaN                 NaN        28.687209
#
#           precip_shift365_clim  precip_shift365_anom  tmp2m_shift365
# 0                    12.476616             -5.272188             NaN  \
# 1                    13.228972             -8.430965             NaN
# 2                    13.862281            -12.190447             NaN
# 3                    14.297970            -13.126262             NaN
# 4                    14.175521            -10.998996             NaN
# ...                        ...                   ...             ...
# 44286280             28.369879             72.344291       18.578002
# 44286281             29.456995             16.003678       19.258619
# 44286282             29.469751             32.462007       18.698177
# 44286283             26.299435             30.347548       18.613803
# 44286284             28.380033              0.307176       19.268811
#
#           tmp2m_sqd_shift365  tmp2m_std_shift365  tmp2m_shift365_clim
# 0                        NaN                 NaN            13.877076  \
# 1                        NaN                 NaN            13.817056
# 2                        NaN                 NaN            13.872171
# 3                        NaN                 NaN            13.829688
# 4                        NaN                 NaN            13.792283
# ...                      ...                 ...                  ...
# 44286280          352.739108            2.756258            14.032610
# 44286281          379.739075            2.973996            14.407670
# 44286282          358.939906            3.052551            13.985285
# 44286283          356.262640            3.128732            13.988793
# 44286284          381.428659            3.184586            14.512959
#
#           tmp2m_shift365_anom
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44286280             4.545392
# 44286281             4.850949
# 44286282             4.712893
# 44286283             4.625010
# 44286284             4.755852
#
# [44286285 rows x 68 columns]
# Loading additional lat lon date features
# Elapsed: 0.7456951141357422s
# Saving lat lon date features to results/regression1/shared/contest_tmp2m_34w/lat_lon_date_data-contest_tmp2m_34wnew.h5
# /home/jovyan/forecast_rodeo/src1/experiments1/experiments_util2.py:1385: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block4_values] [items->Index(['lat', 'lon'], dtype='object')]
#
#   lat_lon_date_data.to_hdf(lat_lon_date_data_file, key="data", mode="w")
# Elapsed: 149.2078697681427s
# Finished generating lat_lon_date_data matrix.
# Total time elapsed: 1398.7605164051056s
